# %% [markdown]
# <a href="https://colab.research.google.com/github/derpen/badappleascii/blob/main/CatDog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 2.9 MB/s
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73051 sha256=16a416a7b9b5a13a6a3525a1188f3748836a1cfe3f79509c1372ec0714aa811a
#   Stored in directory: /root/.cache/pip/wheels/62/d6/58/5853130f941e75b2177d281eb7e44b4a98ed46dd155f556dc5
# Successfully built kaggle
# Installing collected packages: kaggle
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.5.12
#     Uninstalling kaggle-1.5.12:
#       Successfully uninstalled kaggle-1.5.12
# Successfully installed kaggle-1.5.12

# %%
# Upload kaggle.json to download dataset
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-9067c161-7be4-49c0-9040-10a3a33fd593" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9067c161-7be4-49c0-9040-10a3a33fd593">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 76 bytes

# %%
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Downloading dogs-vs-cats.zip to /content
#  98% 799M/812M [00:06<00:00, 130MB/s]
# 100% 812M/812M [00:07<00:00, 120MB/s]

# %%
# !unzip -qo dogs-vs-cats.zip -d dogsvscats
# !unzip -qo dogsvscats/test1.zip -d dogsvscats/test && unzip -qo dogsvscats/train.zip -d dogsvscats/train

# %%
# !ls dogsvscats/train/train | grep cat | wc -l
# !ls dogsvscats/train/train | grep dog | wc -l
# !ls dogsvscats/test/test1 | wc -l
# Out:
# 12500
# 12500
# 12500

# %%
from matplotlib import pyplot
from matplotlib.image import imread
import random

folder = 'dogsvscats/test/test1/'

for i in range(6):
  rand = random.randint(0, 12500)

  pyplot.subplot(3, 3, i + 1)
  
  filename = folder + str(rand) + '.jpg'

  image = imread(filename)
  
  pyplot.imshow(image)

pyplot.suptitle("Le rando pics")
pyplot.show()

# %%
from matplotlib import pyplot
from matplotlib.image import imread
import random

folder = 'dogsvscats/train/train/'

for i in range(6):
  rand = random.randint(0, 12500)
  pyplot.subplot(3, 3, i + 1)
  
  filename = folder + 'cat.' + str(rand) + '.jpg'
  
  image = imread(filename)
  
  pyplot.imshow(image)

pyplot.suptitle("le CATS")
pyplot.show()

# %%
import os
from shutil import copyfile

base_dir = 'dataset_dogs_vs_cats'
test_dir = os.path.join(base_dir, 'test')
train_dir = os.path.join(base_dir, 'train')

test_cats_dir = os.path.join(test_dir, 'cats')
test_dogs_dir = os.path.join(test_dir, 'dogs')

train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

dirs = [base_dir, train_dir, test_dir, test_cats_dir, test_dogs_dir, train_cats_dir, train_dogs_dir]

for dir in dirs:
  os.makedirs(dir, exist_ok=True)

# Split Data
random.seed(1)
# Split 20% to test
val_split = 0.2
src = 'dogsvscats/train/train/'

for files in os.listdir(src):
  src_files = src + files
  if random.random() < val_split:
    if files.startswith('cat'):
      test_cats = test_cats_dir + '/' + files
      copyfile(src_files, test_cats)
    elif files.startswith('dog'):
      test_dogs = test_dogs_dir + '/' + files
      copyfile(src_files, test_dogs)
  else:
    if files.startswith('cat'):
      train_cats = train_cats_dir + '/' + files
      copyfile(src_files, train_cats)
    elif files.startswith('dog'):
      train_dogs = train_dogs_dir + '/' + files
      copyfile(src_files, train_dogs)

# %%
# !rm -rf dataset_dogs_vs_cats/

# %%
# !ls dataset_dogs_vs_cats/test/cats | wc -l
# !ls dataset_dogs_vs_cats/test/dogs | wc -l
# !ls dataset_dogs_vs_cats/train/cats | wc -l
# !ls dataset_dogs_vs_cats/train/dogs | wc -l
# Out:
# 2575
# 2515
# 9925
# 9985

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
 
train_datagen = ImageDataGenerator(
                    # featurewise_center=True,
                    # featurewise_std_normalization=True,
                    rotation_range=45,
                    width_shift_range=0.2,
                    height_shift_range=0.2,
                    horizontal_flip=True,
                    # vertical_flip=True,
                    rescale=1./255
                    ) 
 
test_datagen = ImageDataGenerator(
                    rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir,  
        target_size=(128, 128),  
        batch_size=32,
        class_mode='categorical')
 
test_generator = test_datagen.flow_from_directory(
        test_dir, 
        target_size=(128, 128), 
        batch_size=32,
        class_mode='categorical')
# Out:
# Found 19910 images belonging to 2 classes.
# Found 5090 images belonging to 2 classes.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(128, 128, 3)),
    # tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2, 2),
    # tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    # tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2,2),
    # tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    # tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2,2),
    # tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    # tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D(2,2),
    # tf.keras.layers.Dropout(0.5),

    # tf.keras.layers.Conv2D(512, (3,3), activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    # tf.keras.layers.BatchNormalization(),
    # tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(2, activation='softmax'),
])

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=tf.optimizers.Adam(),
              metrics=['accuracy'])

# %%
# Reduce overfitting

from keras.callbacks import EarlyStopping, ReduceLROnPlateau

earlystop = EarlyStopping(patience=10)

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

callbacks = [earlystop, learning_rate_reduction]

# %%
# Restore the weights
model.load_weights('model.h5')

# %%
epochs = 50

history = model.fit(
      train_generator,
      steps_per_epoch=623,  #  Train size / Batch size
      epochs=epochs,
      validation_data=test_generator, 
      validation_steps=160,  # Validation size / Batch size
      callbacks = callbacks,
      verbose=2)
# Out:
# Epoch 1/50
# 623/623 - 143s - loss: 0.6828 - accuracy: 0.5437 - val_loss: 0.6367 - val_accuracy: 0.6212
# Epoch 2/50
# 623/623 - 141s - loss: 0.6319 - accuracy: 0.6370 - val_loss: 0.5944 - val_accuracy: 0.6674
# Epoch 3/50
# 623/623 - 142s - loss: 0.5783 - accuracy: 0.6949 - val_loss: 0.5368 - val_accuracy: 0.7344
# Epoch 4/50
# 623/623 - 139s - loss: 0.5451 - accuracy: 0.7219 - val_loss: 0.4670 - val_accuracy: 0.7756
# Epoch 5/50
# 623/623 - 140s - loss: 0.5173 - accuracy: 0.7444 - val_loss: 0.4496 - val_accuracy: 0.7912
# Epoch 6/50
# 623/623 - 139s - loss: 0.4875 - accuracy: 0.7598 - val_loss: 0.4098 - val_accuracy: 0.8134
# Epoch 7/50
# 623/623 - 138s - loss: 0.4616 - accuracy: 0.7824 - val_loss: 0.4033 - val_accuracy: 0.8141
# Epoch 8/50
# 623/623 - 138s - loss: 0.4314 - accuracy: 0.8013 - val_loss: 0.3669 - val_accuracy: 0.8377
# Epoch 9/50
# 623/623 - 138s - loss: 0.4118 - accuracy: 0.8148 - val_loss: 0.3723 - val_accuracy: 0.8310
# Epoch 10/50
# 623/623 - 137s - loss: 0.3841 - accuracy: 0.8251 - val_loss: 0.3521 - val_accuracy: 0.8466
# Epoch 11/50
# 623/623 - 138s - loss: 0.3742 - accuracy: 0.8317 - val_loss: 0.3403 - val_accuracy: 0.8503
# Epoch 12/50
# 623/623 - 139s - loss: 0.3558 - accuracy: 0.8427 - val_loss: 0.2997 - val_accuracy: 0.8684
# Epoch 13/50
# 623/623 - 140s - loss: 0.3451 - accuracy: 0.8495 - val_loss: 0.2969 - val_accuracy: 0.8737
# Epoch 14/50
# 623/623 - 140s - loss: 0.3346 - accuracy: 0.8535 - val_loss: 0.3076 - val_accuracy: 0.8621
# Epoch 15/50
# 623/623 - 140s - loss: 0.3192 - accuracy: 0.8586 - val_loss: 0.2630 - val_accuracy: 0.8861
# Epoch 16/50
# 623/623 - 138s - loss: 0.3099 - accuracy: 0.8672 - val_loss: 0.2842 - val_accuracy: 0.8745
# Epoch 17/50
# 623/623 - 138s - loss: 0.2979 - accuracy: 0.8730 - val_loss: 0.2532 - val_accuracy: 0.8917
# Epoch 18/50
# 623/623 - 138s - loss: 0.2918 - accuracy: 0.8741 - val_loss: 0.2466 - val_accuracy: 0.8908
# Epoch 19/50
# 623/623 - 139s - loss: 0.2893 - accuracy: 0.8753 - val_loss: 0.2402 - val_accuracy: 0.8939
# Epoch 20/50
# 623/623 - 139s - loss: 0.2758 - accuracy: 0.8837 - val_loss: 0.2195 - val_accuracy: 0.9065
# Epoch 21/50
# 623/623 - 139s - loss: 0.2670 - accuracy: 0.8855 - val_loss: 0.2146 - val_accuracy: 0.9049
# Epoch 22/50
# 623/623 - 142s - loss: 0.2602 - accuracy: 0.8909 - val_loss: 0.2060 - val_accuracy: 0.9126
# Epoch 23/50
# 623/623 - 142s - loss: 0.2588 - accuracy: 0.8891 - val_loss: 0.2271 - val_accuracy: 0.9037
# Epoch 24/50
# 623/623 - 143s - loss: 0.2578 - accuracy: 0.8918 - val_loss: 0.2476 - val_accuracy: 0.8947
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 25/50
# 623/623 - 141s - loss: 0.2258 - accuracy: 0.9038 - val_loss: 0.1859 - val_accuracy: 0.9187
# Epoch 26/50
# 623/623 - 142s - loss: 0.2230 - accuracy: 0.9057 - val_loss: 0.1834 - val_accuracy: 0.9261
# Epoch 27/50
# 623/623 - 142s - loss: 0.2178 - accuracy: 0.9100 - val_loss: 0.2281 - val_accuracy: 0.9016
# Epoch 28/50
# 623/623 - 143s - loss: 0.2167 - accuracy: 0.9109 - val_loss: 0.1958 - val_accuracy: 0.9189
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 29/50
# 623/623 - 143s - loss: 0.2040 - accuracy: 0.9147 - val_loss: 0.1876 - val_accuracy: 0.9212
# Epoch 30/50
# 623/623 - 142s - loss: 0.1952 - accuracy: 0.9173 - val_loss: 0.1821 - val_accuracy: 0.9261
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 31/50
# 623/623 - 140s - loss: 0.1884 - accuracy: 0.9222 - val_loss: 0.1767 - val_accuracy: 0.9261
# Epoch 32/50
# 623/623 - 140s - loss: 0.1879 - accuracy: 0.9224 - val_loss: 0.1921 - val_accuracy: 0.9198
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 33/50
# 623/623 - 141s - loss: 0.1806 - accuracy: 0.9245 - val_loss: 0.1883 - val_accuracy: 0.9214
# Epoch 34/50
# 623/623 - 142s - loss: 0.1834 - accuracy: 0.9250 - val_loss: 0.1893 - val_accuracy: 0.9200
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 35/50
# 623/623 - 142s - loss: 0.1792 - accuracy: 0.9272 - val_loss: 0.1836 - val_accuracy: 0.9236
# Epoch 36/50
# 623/623 - 139s - loss: 0.1737 - accuracy: 0.9302 - val_loss: 0.1758 - val_accuracy: 0.9253
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 37/50
# 623/623 - 141s - loss: 0.1787 - accuracy: 0.9268 - val_loss: 0.1778 - val_accuracy: 0.9244
# Epoch 38/50
# 623/623 - 143s - loss: 0.1771 - accuracy: 0.9282 - val_loss: 0.1840 - val_accuracy: 0.9220
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 39/50
# 623/623 - 143s - loss: 0.1775 - accuracy: 0.9270 - val_loss: 0.1818 - val_accuracy: 0.9234
# Epoch 40/50
# 623/623 - 141s - loss: 0.1752 - accuracy: 0.9287 - val_loss: 0.1764 - val_accuracy: 0.9244
# Epoch 41/50
# 623/623 - 138s - loss: 0.1733 - accuracy: 0.9284 - val_loss: 0.1791 - val_accuracy: 0.9234
# Epoch 42/50
# 623/623 - 145s - loss: 0.1724 - accuracy: 0.9300 - val_loss: 0.1793 - val_accuracy: 0.9232
# Epoch 43/50
# 623/623 - 140s - loss: 0.1745 - accuracy: 0.9285 - val_loss: 0.1791 - val_accuracy: 0.9248
# Epoch 44/50
# 623/623 - 141s - loss: 0.1752 - accuracy: 0.9275 - val_loss: 0.1827 - val_accuracy: 0.9228
# Epoch 45/50
# 623/623 - 143s - loss: 0.1768 - accuracy: 0.9280 - val_loss: 0.1789 - val_accuracy: 0.9250
# Epoch 46/50
# 623/623 - 141s - loss: 0.1748 - accuracy: 0.9283 - val_loss: 0.1834 - val_accuracy: 0.9222

# %%
import numpy as np
from google.colab import files
from keras.preprocessing import image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

uploaded = files.upload()

for fn in uploaded.keys():
 
  # predicting images
  path = fn
  img = image.load_img(path, target_size=(128,128))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  
  if classes[0][0]==1:
    print('cats')
  else:
    print('dogs')
# Out:
#      <input type="file" id="files-ef23996a-dc66-4053-b7f9-0ff531d1485f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ef23996a-dc66-4053-b7f9-0ff531d1485f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test4.jpg to test4.jpg
# test4.jpg
# [[0. 1.]]
# dogs

# %%
from matplotlib import pyplot
from matplotlib.image import imread
from keras.preprocessing import image
import random

folder = 'dogsvscats/test/test1/'

for i in range(6):
  rand = random.randint(0, 12500)

  pyplot.subplot(3, 3, i + 1)

  path = folder + str(rand) + '.jpg'

  testimage = image.load_img(path, target_size=(128,128))
  imgplot = plt.imshow(testimage)
  x = image.img_to_array(testimage)
  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size=10)
  
  if classes[0][0]==1:
    plt.xlabel('Cat')
  else:
    plt.xlabel('Dog')
  
plt.tight_layout()
pyplot.suptitle("Le predict pics")
pyplot.show()

# %%
model.save_weights("model.h5")

# %%
# TO DO : LE PREDICT
